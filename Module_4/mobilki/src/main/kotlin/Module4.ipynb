// %%
%use coroutines

// %%
// Out:
// Пользователи:
//   - Alice
//   - Bob
//   - Ivan
//   - Olga
//
// Продажи за день:
//   Coffee → 1680 ₽
//   Tea → 475 ₽
//
// Погода:
//   Москва: -18°C, снег
//   New York: -5°C, облачно
//   Токио: 11°C, дождь
// Время выполнения: 2604s
